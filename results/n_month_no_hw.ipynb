# %%
import sys
sys.path.insert(0, '..')
sys.path.insert(0, '../exposure_to_hazards/')

from config import FIGURES, DATA_DIR 
from pathlib import Path

# %% [markdown]
# Which country has the highest number of vulnerable (below 1 or over 65) people that have been exposed on average per month to any health hazard relative to the total population?

# %%
import itertools
from climada.engine import Impact
combinations = []

hazards = ['RF','EP','DR','FI','TC']

for r in range(1, len(hazards) + 1):
    combinations.extend(list(itertools.combinations(hazards, r)))

combinations = ["-".join(combi) for combi in combinations]

# %%
from pathlib import Path
IMPACT_DIR =DATA_DIR /  'impacts'


imp_combined = {}
for age in ['all', '0_1', '65_70_75_80']:
    imp_combined[age] = {}
    for combi in combinations:
        imp_combined[age][combi] = Impact.from_csv(IMPACT_DIR / f"csv/{combi}_{age}_2003_2022.csv")
        imp_combined[age][combi].imp_mat = Impact.read_sparse_csr(IMPACT_DIR / f"npz/{combi}_{age}_2003_2022.npz")
        imp_combined[age][combi]
# Out:
# 2024-09-06 09:46:40,707 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:46:41,296 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:46:41,892 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:46:42,431 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:46:42,966 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:46:43,492 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:46:44,033 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:46:44,601 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:46:45,160 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:46:45,671 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:46:46,190 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:46:46,702 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:46:47,220 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:46:47,737 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:46:48,272 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:46:48,924 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:46:49,447 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:46:49,976 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:46:50,522 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:46:51,043 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:46:51,571 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:46:52,079 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:46:52,598 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:46:53,101 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:46:53,626 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:46:54,207 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:46:54,737 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:46:55,281 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:46:55,785 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:46:56,292 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:46:56,792 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:46:57,319 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:46:57,864 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:46:58,404 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:46:58,934 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:46:59,458 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:00,026 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:00,544 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:01,043 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:01,567 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:02,088 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:02,612 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:03,144 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:03,654 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:04,159 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:04,672 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:05,170 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:05,696 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:06,324 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:06,939 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:07,563 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:08,105 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:08,655 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:09,207 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:09,763 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:10,312 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:10,843 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:11,382 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:11,924 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:12,481 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:13,011 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:13,553 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:14,104 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:14,667 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:15,248 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:15,811 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:16,327 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:16,861 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:17,391 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:17,913 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:18,438 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:18,980 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:19,484 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:19,991 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:20,504 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:21,012 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:21,541 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:22,065 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:22,578 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:23,112 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:23,618 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:24,104 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:24,656 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:25,342 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:25,836 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:26,332 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:26,840 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:27,327 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:27,818 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:28,307 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:28,787 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:29,274 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-09-06 09:47:29,794 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)

# %%
from pathlib import Path
from climada.entity import Exposures
import numpy as np
exposures_dict = {}

total_pop = {}

for age in ['all', '0_1', '65_70_75_80']:
    exposures_dict[age] = {}
    total_pop[age] = {}

    for year in np.arange(2003, 2023):
        year = str(year)
        exposures_dict[age][year] = Exposures.from_hdf5(DATA_DIR / f"population/worldpop/climada_exposures/{age}_era5_025_compatible_{year}.hdf5")
        exposures_dict[age][year].gdf["impf_RF"] = 1 
        exposures_dict[age][year].gdf['longitude'] = exposures_dict[age][year].gdf['longitude'].apply(lambda x: x - 360 if x > 180 else x)
        exposures_dict[age][year].gdf['value'][exposures_dict[age][year].gdf['value']<0] = 0
        total_pop[age][year] = exposures_dict[age][year].gdf['value'].sum()

# %%
three_tuple_keys = [key for key in imp_combined['all'].keys() if len(key.replace("RF_2y","RF")) == 8]
single_tuple_keys = [key for key in imp_combined[age].keys() if len(key.replace("RF_2y","RF")) == 2]
double_tuple_keys = [key for key in imp_combined[age].keys() if len(key.replace("RF_2y","RF")) == 5]


imp_combined_three_hazards = {
    age: {
        key: imp_combined[age][key]
        for key in three_tuple_keys
        if imp_combined[age][key].imp_mat.nnz > 0
    }
    for age in imp_combined
}

imp_combined_one_hazard = {
    age: {
        key: imp_combined[age][key]
        for key in single_tuple_keys
        if imp_combined[age][key].imp_mat.nnz > 0
    }
    for age in imp_combined
}

imp_combined_two_hazard = {
    age: {
        key: imp_combined[age][key]
        for key in double_tuple_keys
        if imp_combined[age][key].imp_mat.nnz > 0
    }
    for age in imp_combined
}

# %%
from climada.util.multi_risk import *
at_least_three_hazards = {}
for age in imp_combined:
    at_least_three_hazards[age] = combine_impacts(imp_combined_three_hazards[age], how="max")

at_least_one_hazards = {}
for age in imp_combined:
    at_least_one_hazards[age] = combine_impacts(imp_combined_one_hazard[age], how="max")

at_least_two_hazards = {}
for age in imp_combined:
    at_least_two_hazards[age] = combine_impacts(imp_combined_two_hazard[age], how="max")

# %%
import pandas as pd

total_impact_per_person = {}
for age in ['all', '0_1', '65_70_75_80']:
    total_impact_per_person[age] = {}
    for combi in combinations:
        total_months = imp_combined[age][combi].imp_mat.shape[0]
        total_impact_per_person[age][combi] = np.sum([imp_combined[age][combi].imp_mat[n*12-12:n*12].sum()/total_pop[age][str(n + 2003)] for n in range(1,int(total_months/12))])
    total_impact_per_person[age]['Three or more'] = np.sum([at_least_three_hazards[age].imp_mat[n*12-12:n*12].sum()/total_pop[age][str(n + 2003)] for n in range(1,int(total_months/12))])
    total_impact_per_person[age]['Two or more'] = np.sum([at_least_two_hazards[age].imp_mat[n*12-12:n*12].sum()/total_pop[age][str(n + 2003)] for n in range(1,int(total_months/12))])
    total_impact_per_person[age]['One or more'] = np.sum([at_least_one_hazards[age].imp_mat[n*12-12:n*12].sum()/total_pop[age][str(n + 2003)] for n in range(1,int(total_months/12))])

df = pd.DataFrame(total_impact_per_person)
df = df[df.sum(axis=1)>0.01]
df = df.rename(index=lambda x: x.replace('RF_2y', 'RF'))
index_order = list(df.index)

# %%
total_impact_per_person_period1 = {}
for age in ['all', '0_1', '65_70_75_80']:
    total_impact_per_person_period1[age] = {}
    for combi in combinations:
        total_months = imp_combined[age][combi].imp_mat.shape[0]
        total_impact_per_person_period1[age][combi] = np.sum([imp_combined[age][combi].imp_mat[n*12-12:n*12].sum()/total_pop[age][str(n + 2003)] for n in range(1,11)])
        total_impact_per_person_period1[age]['Three or more'] = np.sum([at_least_three_hazards[age].imp_mat[n*12-12:n*12].sum()/total_pop[age][str(n + 2003)] for n in range(1,11)])
        total_impact_per_person_period1[age]['Two or more'] = np.sum([at_least_two_hazards[age].imp_mat[n*12-12:n*12].sum()/total_pop[age][str(n + 2003)] for n in range(1,11)])

        total_impact_per_person_period1[age]['One or more'] = np.sum([at_least_one_hazards[age].imp_mat[n*12-12:n*12].sum()/total_pop[age][str(n + 2003)] for n in range(1,11)])


df1 = pd.DataFrame(total_impact_per_person_period1)
df1 = df1.reindex(index_order)
#df1= df1[df1.sum(axis=1)>0]

# %%
total_impact_per_person_period2 = {}
for age in ['all', '0_1', '65_70_75_80']:
    total_impact_per_person_period2[age] = {}
    for combi in combinations:
        total_months = imp_combined[age][combi].imp_mat.shape[0]
        total_impact_per_person_period2[age][combi] = np.sum([imp_combined[age][combi].imp_mat[n*12-12:n*12].sum()/total_pop[age][str(n + 2003)] for n in range(10,20)])
        total_impact_per_person_period2[age]['Three or more'] = np.sum([at_least_three_hazards[age].imp_mat[n*12-12:n*12].sum()/total_pop[age][str(n + 2003)] for n in range(10,20)])
        total_impact_per_person_period2[age]['Two or more'] = np.sum([at_least_two_hazards[age].imp_mat[n*12-12:n*12].sum()/total_pop[age][str(n + 2003)] for n in range(10,20)])

        total_impact_per_person_period2[age]['One or more'] = np.sum([at_least_one_hazards[age].imp_mat[n*12-12:n*12].sum()/total_pop[age][str(n + 2003)] for n in range(10,20)])

df2 = pd.DataFrame(total_impact_per_person_period2)
df2 = df2.reindex(index_order)
df1 = df1.round(3)
#df2= df2[df2.sum(axis=1)>0]

# %%
df_diff = 100*(df2-df1)/df1
df_diff = df_diff.reindex(index_order)
df_diff = df_diff.rename(index=lambda x: x.replace('RF_2y', 'RF'))
df_diff = df_diff.dropna()

# %%
combis = ['HW',
 'DR-HW',
 'HW-FI',
 'DR-HW-FI',
 'Three or more',
 'RF',
 'EP',
 'DR',
 'FI',
 'TC',
 'RF-EP',
 'RF-DR',
 'RF-HW',
 'RF-TC',
 'EP-DR',
 'EP-HW',
 'EP-FI',
 'EP-TC',
 'DR-FI',
 'DR-TC',
 'HW-TC',
 'RF-EP-DR',
 'RF-EP-HW',
 'RF-EP-TC',
 'RF-HW-TC',
 'EP-DR-HW',
 'EP-HW-FI',
 'EP-HW-TC',
 'One or more',
 'Two or more',
 'Three or more']
df  = pd.concat([df,df_diff],axis=1)
df = df.round(3)

df[df.index.isin(combis)]
# Out:
#                   all     0_1  65_70_75_80      all      0_1  65_70_75_80
# RF              1.064   1.060        0.999   -5.407  -10.004       -0.853
# EP              6.310   6.624        6.027   10.332   13.994        6.234
# DR              5.135   5.294        4.707   -3.114   -2.322       -6.988
# FI              0.755   0.939        0.621   -0.387   -0.677        0.188
# TC              0.300   0.222        0.511   -9.637  -12.749        0.478
# RF-EP           0.197   0.199        0.170    9.356    6.595       16.625
# RF-DR           0.014   0.018        0.009  -12.358  -22.008      -16.194
# RF-TC           0.005   0.004        0.007  -18.758   -9.256      -12.604
# EP-DR           0.051   0.063        0.038    3.300   -8.617       12.427
# EP-FI           0.008   0.007        0.009  108.518  101.747       59.836
# EP-TC           0.075   0.055        0.124  -11.476  -11.671        1.248
# DR-FI           0.050   0.049        0.049   -6.833  -18.739        9.223
# RF-EP-TC        0.003   0.002        0.005  -25.026   24.467      -29.434
# Three or more   0.004   0.004        0.005   10.732    7.933      -15.834
# Two or more     0.392   0.388        0.395    3.080   -1.305       11.046
# One or more    13.168  13.747       12.465    2.754    4.482       -0.072

# %%
df.loc['Two or more']
# Out:
# all             0.392
# 0_1             0.388
# 65_70_75_80     0.395
# all             3.080
# 0_1            -1.305
# 65_70_75_80    11.046
# Name: Two or more, dtype: float64

# %%
exp = exposures_dict[age]['2003']
imp_mat = imp_combined[age]['FI'].imp_mat[0:12]
m1 = imp_combined[age]['FI'].imp_mat[0:12].data
m2 = np.array(exp.gdf.value[imp_mat.nonzero()[1]])
np.sum(m1>m2)
# Out:
# 0

# %%
import copy
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 12})  # You can adjust the size as needed

pair_tuple_keys = [key for key in imp_combined[age].keys() if len(key) == 5]

# Load a world map to use as a land mask
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))


gdf =at_least_three_hazards[age]._build_exp().gdf
imp_mat = copy.deepcopy(at_least_three_hazards[age].imp_mat)
imp_mat.data[imp_mat.data < 1] = 0
imp_mat.data[imp_mat.data >= 1] = 1


gdf['value'] = np.asarray(imp_mat.sum(axis=0))[0]
gdf['geometry'] = gpd.points_from_xy(gdf.longitude, gdf.latitude)

# Determine dynamic vmax
vmax = gdf['value'][gdf['value']>0].quantile(0.99)  # Set vmax to the 95th percentile of the data

# Plot the world map with only the land areas colored

# Overlay the geodataframe with the values
gdf.value[gdf.value==0] = np.nan
if vmax==0:
    vmax=2
fig, ax = plt.subplots(figsize=(10, 5))
world.plot(ax=ax, color='lightgrey')
gdf['value'][gdf['value']>0] = gdf['value'][gdf['value']>0].astype(int)
gdf.plot(column='value', ax=ax, markersize=0.01, cmap='viridis', vmin=1, vmax=vmax)
cbar = plt.cm.ScalarMappable(norm=plt.Normalize(vmin=1, vmax=vmax))
ax_cbar = fig.colorbar(cbar, ax=ax, orientation='horizontal') 
ax_cbar.set_label(f'Number of months', fontsize=12)

# Set plot title and labels
ax.set_title(f'At least three')

ax.set_xticks([])  # Remove x-axis ticks
ax.set_yticks([])  
#plt.savefig(FIGURES / f"nmonth_{combi}.png", bbox_inches='tight', dpi=1200)
# Out:
# /var/folders/f5/lms0b90j1kx7kk4v552qkjqw0000gp/T/ipykernel_26873/3580614170.py:10: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# /var/folders/f5/lms0b90j1kx7kk4v552qkjqw0000gp/T/ipykernel_26873/3580614170.py:20: FutureWarning: You are adding a column named 'geometry' to a GeoDataFrame constructed without an active geometry column. Currently, this automatically sets the active geometry column to 'geometry' but in the future that will no longer happen. Instead, either provide geometry to the GeoDataFrame constructor (GeoDataFrame(... geometry=GeoSeries()) or use `set_geometry('geometry')` to explicitly set the active geometry column.
#   gdf['geometry'] = gpd.points_from_xy(gdf.longitude, gdf.latitude)
# []

# %%
import copy
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 12})  # You can adjust the size as needed

pair_tuple_keys = [key for key in imp_combined[age].keys() if len(key) == 5]

# Load a world map to use as a land mask
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))


gdf =at_least_one_hazards[age]._build_exp().gdf
imp_mat = copy.deepcopy(at_least_one_hazards[age].imp_mat)
imp_mat.data[imp_mat.data < 1] = 0
imp_mat.data[imp_mat.data >= 1] = 1


gdf['value'] = np.asarray(imp_mat.sum(axis=0))[0]
gdf['geometry'] = gpd.points_from_xy(gdf.longitude, gdf.latitude)

# Determine dynamic vmax
vmax = gdf['value'][gdf['value']>0].quantile(0.999)  # Set vmax to the 95th percentile of the data

# Plot the world map with only the land areas colored

# Overlay the geodataframe with the values
gdf.value[gdf.value==0] = np.nan
if vmax==0:
    vmax=2
fig, ax = plt.subplots(figsize=(10, 5))
world.plot(ax=ax, color='lightgrey')
gdf['value'][gdf['value']>0] = gdf['value'][gdf['value']>0].astype(int)
gdf.plot(column='value', ax=ax, markersize=0.01, cmap='viridis', vmin=1, vmax=vmax)
cbar = plt.cm.ScalarMappable(norm=plt.Normalize(vmin=1, vmax=vmax))
ax_cbar = fig.colorbar(cbar, ax=ax, orientation='horizontal') 
ax_cbar.set_label(f'Number of months', fontsize=12)

# Set plot title and labels
ax.set_title(f'At least one')

ax.set_xticks([])  # Remove x-axis ticks
ax.set_yticks([])  
#plt.savefig(FIGURES / f"nmonth_{combi}.png", bbox_inches='tight', dpi=1200)
# Out:
# /var/folders/f5/lms0b90j1kx7kk4v552qkjqw0000gp/T/ipykernel_26873/2329363195.py:10: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# /var/folders/f5/lms0b90j1kx7kk4v552qkjqw0000gp/T/ipykernel_26873/2329363195.py:20: FutureWarning: You are adding a column named 'geometry' to a GeoDataFrame constructed without an active geometry column. Currently, this automatically sets the active geometry column to 'geometry' but in the future that will no longer happen. Instead, either provide geometry to the GeoDataFrame constructor (GeoDataFrame(... geometry=GeoSeries()) or use `set_geometry('geometry')` to explicitly set the active geometry column.
#   gdf['geometry'] = gpd.points_from_xy(gdf.longitude, gdf.latitude)
# []

# %%
FIGURES = Path("/Users/szelie/Dropbox/Applications/Overleaf/health_multi_risk_SI")

# %%
import copy
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
from cartopy import crs

plt.rcParams.update({'font.size': 12})  # Adjust the size as needed

pair_tuple_keys = [key for key in imp_combined[age].keys() if len(key) == 5]

# Load a world map to use as a land mask
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Filter combinations
filtered_combis = [combi for combi in imp_combined[age] if len(combi) <= 8 or "RF" not in combi]

# Create a figure with 8 rows and 4 columns, with reduced row spacing
fig, axes = plt.subplots(8, 4, figsize=(20, 20), gridspec_kw={'hspace': 0.05})  # Reduced hspace here
axes = axes.flatten()
r = 0
plots_created = 0
# Iterate over the valid combinations and plot
age = 'all'
imp_combined[age]['One or more'] = at_least_one_hazards[age]
imp_combined[age]['Two or more'] = at_least_two_hazards[age]
imp_combined[age]['Three or more'] = at_least_three_hazards[age]

for idx, combi in enumerate(imp_combined[age]):
    idx = idx - r

    if imp_combined['all'][combi].at_event.max() < 1e6:
        r = r + 1
        continue
    
    gdf = imp_combined[age][combi]._build_exp().gdf
    
    imp_mat = copy.deepcopy(imp_combined[age][combi].imp_mat)
    imp_mat.data[imp_mat.data < 1] = 0

    imp_mat.data[imp_mat.data >= 1] = 1

    gdf['value'] = np.asarray(imp_mat.sum(axis=0))[0]
    
    gdf = gpd.GeoDataFrame(gdf, geometry=gpd.points_from_xy(gdf.longitude, gdf.latitude))
    
    gdf['value'][gdf['value'] == 0] = np.nan
    robinson = crs.Robinson().proj4_init
    world = world.to_crs(robinson)
    world.plot(ax=axes[idx], color='lightgrey')
    gdf['value'][gdf['value'] > 0] = gdf['value'][gdf['value'] > 0].astype(int)
    gdf.set_crs("epsg:4326", inplace=True)
    gdf = gdf.to_crs(robinson)
    
    # Calculate the 99th percentile for each combination
    vmax_local = gdf['value'][gdf['value'] > 0].quantile(0.99)

    # Plot the data
    gdf.plot(column='value', ax=axes[idx], markersize=0.01, cmap='viridis', vmin=1, vmax=vmax_local)

    # Add a colorbar for each subplot
    norm = Normalize(vmin=1, vmax=vmax_local)
    sm = ScalarMappable(cmap='viridis', norm=norm)
    sm._A = []  # Empty the array for ScalarMappable (required by matplotlib)
    cbar = fig.colorbar(sm, ax=axes[idx], orientation='vertical', shrink=0.7)

    axes[idx].set_title(combi.replace("_2y", ""), fontsize=12)
    axes[idx].set_xticks([])
    axes[idx].set_yticks([])
    plots_created += 1
for ax in axes[plots_created:]:
    ax.set_visible(False)


# Adjust layout to reduce space between plots vertically
plt.tight_layout()
plt.subplots_adjust(hspace=0.05)  # Adjust this value to reduce vertical space between rows

#plt.savefig(FIGURES / "nmonth_all.png", bbox_inches='tight', dpi=400)
plt.show()
# Out:
# /var/folders/f5/lms0b90j1kx7kk4v552qkjqw0000gp/T/ipykernel_26873/3919731491.py:14: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# /var/folders/f5/lms0b90j1kx7kk4v552qkjqw0000gp/T/ipykernel_26873/3919731491.py:77: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
gdf.value.sum()

# %%
import copy
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize, TwoSlopeNorm
from matplotlib.cm import ScalarMappable
from cartopy import crs

plt.rcParams.update({'font.size': 12})  # Adjust the size as needed

# Load a world map to use as a land mask
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Create a figure with 8 rows and 4 columns, with reduced row spacing
fig, axes = plt.subplots(8, 4, figsize=(20, 20))  # Reduced hspace here
axes = axes.flatten()
r = 0
plots_created = 0

# Iterate over the valid combinations and plot

imp_combined['all']['One or more'] = at_least_one_hazards[age]
imp_combined['all']['Two or more'] = at_least_two_hazards[age]
imp_combined['all']['Three or more'] = at_least_three_hazards[age]
for idx, combi in enumerate(imp_combined['all']):
    idx = idx - r
 
    if imp_combined['all'][combi].at_event.max() < 1e6:
        r = r + 1
        continue
    
    gdf = imp_combined['all'][combi]._build_exp().gdf
    
    imp_mat = copy.deepcopy(imp_combined['all'][combi].imp_mat)
    imp_mat.data[imp_mat.data < 1] = 0
    imp_mat.data[imp_mat.data >= 1] = 1

    # Calculate the difference between the first period (2003-2012) and the second period (2013-2021)
    gdf['value'] = np.asarray(imp_mat[108:].sum(axis=0) - imp_mat[0:120].sum(axis=0))[0]
    
    gdf = gpd.GeoDataFrame(gdf, geometry=gpd.points_from_xy(gdf.longitude, gdf.latitude))
    robinson = crs.Robinson().proj4_init
    world = world.to_crs(robinson)
    world.plot(ax=axes[idx], color='lightgrey')
    gdf = gdf[gdf.value!=0]
    if len(gdf)<100:
        continue
    gdf.set_crs("epsg:4326", inplace=True)
    gdf = gdf.to_crs(robinson)
    
    # Calculate the 99th percentile for the colorbar limit
    vmax_local = np.quantile(gdf['value'],0.99)
    vmin_local = np.quantile(gdf['value'],0.01)
    vmin_abs = abs(vmin_local)
    vmax = np.max([vmin_abs,vmax_local])
    if vmax==0:
        continue


    # Plot the data using the 'coolwarm' colormap, which has blue for negative values and red for positive values
    norm = TwoSlopeNorm(vmin=-vmax, vcenter=0, vmax=vmax)
    gdf.plot(column='value', ax=axes[idx], markersize=0.01, cmap='coolwarm', norm=norm)

    # Add a colorbar for each subplot
    sm = ScalarMappable(cmap='coolwarm', norm=norm)
    sm._A = []  # Empty the array for ScalarMappable (required by matplotlib)
    cbar = fig.colorbar(sm, ax=axes[idx], orientation='vertical', shrink=0.7)
    #Ecbar.set_label('Difference', fontsize=12)

    axes[idx].set_title(combi.replace("_2y", ""), fontsize=12)
    axes[idx].set_xticks([])
    axes[idx].set_yticks([])
    plots_created += 1

# Hide any remaining unused subplots
for ax in axes[plots_created:]:
    ax.set_visible(False)

# Adjust layout to reduce space between plots vertically
plt.tight_layout()
plt.subplots_adjust(hspace=0.05)
#plt.savefig(FIGURES / "nmonth_change.png", bbox_inches='tight', dpi=300)

plt.show()
# Out:
# /var/folders/f5/lms0b90j1kx7kk4v552qkjqw0000gp/T/ipykernel_26873/3939146922.py:12: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
imp_combined['all']

# %%
np.maxvmax_local

# %%
imp_combined[age][combi].imp_mat[108:]
