# %%
# plotting functions, can be improved for readabiolityh

# %%
import sys
sys.path.insert(0, '..')
sys.path.insert(0, '../exposure_to_hazards/')

from config import FIGURES, HAZARDS, DATA_DIR

# %%
import geopandas as gpd
import pandas as pd
from cartopy import crs
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
from pathlib import Path

import itertools
from climada.engine import Impact
combinations = []

hazards = ['RF','EP','DR','HW','FI','TC']

for r in range(1, len(hazards) + 1):
    combinations.extend(list(itertools.combinations(hazards, r)))

combinations = ["-".join(combi) for combi in combinations]

IMPACT_DIR = DATA_DIR / "impacts/multi_haz"

imp_combined = {}
for age in ['all', '0_1', '65_70_75_80']:
    imp_combined[age] = {}
    for combi in combinations:
        imp_combined[age][combi] = Impact.from_csv(IMPACT_DIR / f"csv/{combi}_{age}_2003_2022.csv")
        imp_combined[age][combi].imp_mat = Impact.read_sparse_csr(IMPACT_DIR / f"npz/{combi}_{age}_2003_2022.npz")
        imp_combined[age][combi]
# Out:
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:23,725 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# 2024-08-22 08:46:24,548 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:25,311 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:26,022 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# 2024-08-22 08:46:26,633 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:27,271 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# 2024-08-22 08:46:27,792 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:28,399 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:28,922 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:29,557 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:30,117 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:30,653 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:31,256 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:31,788 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:32,327 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:32,906 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:33,483 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:33,978 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:34,506 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:34,990 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:35,504 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:36,008 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:36,539 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:37,138 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:37,706 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:38,168 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:38,682 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:39,285 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:39,824 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:40,341 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:40,816 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:41,361 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:41,866 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:42,353 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:42,849 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:43,403 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:43,895 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:44,413 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:44,922 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:45,416 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:45,937 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:46,447 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:46,910 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:47,384 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:47,838 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:48,310 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:48,802 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:49,264 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:49,727 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:50,247 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:50,823 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:51,348 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:51,850 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:52,382 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:52,979 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:53,547 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:54,051 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:54,560 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:55,189 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:55,731 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:56,203 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:56,756 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:57,249 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:57,753 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:58,470 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# 2024-08-22 08:46:59,059 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:46:59,876 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:00,543 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:01,230 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:01,720 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:02,205 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:02,817 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:03,313 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:03,811 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:04,387 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:04,902 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:05,406 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:05,901 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:06,409 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:06,911 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:07,417 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:07,919 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:08,437 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:08,996 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:09,484 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:09,944 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:10,402 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:10,855 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:11,330 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:11,799 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:12,253 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:12,719 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:13,169 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:13,628 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:14,090 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:14,577 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:15,067 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:15,570 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:16,067 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:16,727 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:17,248 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:17,762 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:18,256 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:18,744 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:19,201 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:19,674 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# ...
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:46,270 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:46,758 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:47,221 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:47,723 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:48,207 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:48,704 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:49,187 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:49,726 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:50,203 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:50,697 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:51,200 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:51,709 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:52,191 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:52,642 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:53,175 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:53,672 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:54,160 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:54,662 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:55,135 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:55,638 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:56,267 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:56,768 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:57,356 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:57,924 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:58,535 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:59,047 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:47:59,552 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:48:00,047 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:48:00,555 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:48:01,052 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:48:01,518 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:48:01,994 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:48:02,496 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:48:02,987 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,5,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# 2024-08-22 08:48:03,537 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:1081: DtypeWarning: Columns (1,8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)

# %%
def calculate_risk_score(imp_combined, agg_regions, gdf_adm1, adm1_pop_by_year, age, hazards, risk_score_type):
    """
    Calculate and visualize the risk score for a specified age group and number of hazards.

    This function processes impact data based on the age group and the number of hazards. It calculates either 
    the absolute impact or the relative impact (per population) and generates a world map visualizing the risk 
    scores at the regional level.

    Parameters:
    -----------
    imp_combined : dict with impact combination
    age : str
        Age group to consider (e.g., 'all', '0_1', '65_70_75_80').
    hazards : int
        Number of hazards to consider (1, 2, or 3).
    risk_score_type : str
        Type of risk score to calculate ('impact' for absolute impact, 'relative_impact' for relative impact per population).

    Returns:
    --------
    gdf_merged : GeoDataFrame
        A GeoDataFrame containing the merged data with calculated risk scores, ready for geographical visualization.

    Raises:
    -------
    ValueError:
        If the number of hazards is not 1, 2, or 3.

    Example:
    --------
    result = calculate_risk_score('all', 3, 'impact')
    """
    
    # Validate the number of hazards
    if hazards not in [1, 2, 3]:
        raise ValueError("Hazards must be 1, 2, or 3.")
    
    # Identify the appropriate keys based on the number of hazards
    if hazards == 3:
        tuple_keys = [key for key in imp_combined[age].keys() if len(key.replace("RF_2y","RF")) == 8]
    elif hazards == 2:
        tuple_keys = [key for key in imp_combined[age].keys() if len(key.replace("RF_2y","RF")) == 5]
    else:
        tuple_keys = [key for key in imp_combined[age].keys() if len(key.replace("RF_2y","RF")) == 2]
    
    # Filter the impacts based on the number of hazards
    imp_combined_subset = {
        key: imp_combined[age][key]
        for key in tuple_keys
        if imp_combined[age][key].imp_mat.nnz > 0
    }
    
    # Combine impacts using "max" method for at least the specified number of hazards
    imp_combined_all = combine_impacts(imp_combined_subset, how="max")
    
    # Aggregate impacts at the regional level
    at_reg = imp_combined_all.impact_at_reg(agg_regions=agg_regions['numeric'])
    
    # Prepare the data for plotting
    at_reg['month'] = [datetime.datetime.fromordinal(int(date)).month for date in imp_combined[age][tuple_keys[0]].date]
    at_reg['year'] = [datetime.datetime.fromordinal(int(date)).year for date in imp_combined[age][tuple_keys[0]].date]
    
    # Melt and merge data
    at_reg_melted = at_reg.melt(id_vars=['month', 'year'], var_name='numeric', value_name='impact')
    at_reg_melted = at_reg_melted.merge(agg_regions[["ADM1_ID", "ADM1_NAME", "ISO3", "numeric"]].drop_duplicates())
    at_reg_melted = at_reg_melted.merge(adm1_pop_by_year, on=['year', "ADM1_ID", "ADM1_NAME", "ISO3"], how='inner')
    
    # Calculate relative impact if needed
    if risk_score_type == 'relative_impact':
        at_reg_melted['relative_impact'] = at_reg_melted['impact'] / at_reg_melted['value']
        at_reg_melted['Risk Score'] = at_reg_melted['relative_impact']
    else:
        at_reg_melted['Risk Score'] = at_reg_melted['impact']


    return at_reg_melted

# %%
import matplotlib.pyplot as plt
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib as mpl
from cartopy import crs
from plot_functions import *


# Function to normalize a column in a DataFrame after aggregation
def normalize_data(data, column):
    min_val = data[column].min()
    max_val = data[column].max()
    data[f'Normalized {column}'] = (data[column] - min_val) / (max_val - min_val)
    return data

agg_regions = pd.read_csv(DATA_DIR / "population/all_worldpop_admin_by_point.csv")
agg_regions['numeric'] = pd.factorize(agg_regions["ADM1_ID"])[0]
adm1_pop_by_year = pd.read_csv(DATA_DIR / "population/all_worldpop_by_admin1_by_year_2000_2022.csv")
gdf_adm1 = gpd.read_file(DATA_DIR / "population/geoBoundariesCGAZ_ADM1_renamed/geoBoundariesCGAZ_ADM1.shp")

titles = [
    "$R_{1,a}$ - One or more, Absolute values",
    "$R_{1,r}$ - One or more, Relative to total population",
    "$R_{3,a}$ - Three or more, Absolute values",
    "$R_{3,r}$ - Three or more, Relative to total population",
    "$R_{3,r, u5}$ - Three or more, Relative to total population, Under 5",
    "$R_{3,r, O65}$ - Three or more, Relative to total population, Over 65"
]

# Parameters for different risk scores, now correctly set to use only relative impact for under 5 and over 65
risk_parameters = {
    "One or more: all (absolute)": {'age': 'all', 'hazards': 1, 'risk_score_type': 'impact'},
    "One or more: all (relative)": {'age': 'all', 'hazards': 1, 'risk_score_type': 'relative_impact'},
    "Three or more: all (absolute)": {'age': 'all', 'hazards': 3, 'risk_score_type': 'impact'},
    "Three or more: all (relative)": {'age': 'all', 'hazards': 3, 'risk_score_type': 'relative_impact'},
    "Under 5 (relative)": {'age': '0_1', 'hazards': 3, 'risk_score_type': 'relative_impact'},
    "Over 65 (relative)": {'age': '65_70_75_80', 'hazards': 3, 'risk_score_type': 'relative_impact'}
}


# Generate the risk scores using the calculate_risk_score function with imp_combined as an argument
risk_score_data = {description: calculate_risk_score(imp_combined, agg_regions, gdf_adm1, adm1_pop_by_year, **params) for description, params in risk_parameters.items()}



# Initialize the figure
fig, axs = plt.subplots(3, 2, figsize=(15, 12), subplot_kw={'projection': crs.Robinson()})
plt.subplots_adjust(hspace=0.02, wspace=0.02, bottom=0.15)

# Define colormap
cmap = 'cividis_r'
max_values = []
plot_index = 0
alphabet = ['a', 'b', 'c', 'd', 'e', 'f']

# Container to store top 5 hotspots for each risk parameter
top_5_hotspots = {}

# Plot each risk score
for description, gdf in risk_score_data.items():

 # Calculate the mean impact across months for each region
    mean_imp_at_reg = gdf.groupby(["ADM1_ID", "ADM1_NAME", "ISO3"]).mean().reset_index()
    
    # Prepare the geographical data
    robinson = crs.Robinson().proj4_init
    gdf_merged = gdf_adm1.merge(mean_imp_at_reg, on=["ADM1_ID", "ADM1_NAME", "ISO3"], how='right')
    gdf_merged["geometry"] = gdf_merged["geometry"].clip((-180, -59.48, 179.9999999, 83.64))
    gdf_merged = gdf_merged.to_crs(robinson)
    
    impact_type = 'relative_impact' if 'under 5' in description.lower() or 'over 65' in description.lower() else 'impact'
    
    column = 'Risk Score'
    gdf_merged = normalize_data(gdf_merged, column)
    column = f'Normalized {column}'

    norm = mpl.colors.Normalize(vmin=gdf_merged[column].min(), vmax=gdf_merged[column].quantile(0.999))

    ax = axs[plot_index // 2, plot_index % 2]
    gdf_merged.plot(column=column, cmap=cmap, ax=ax, norm=norm)

    # Modify title to include alphabetical label, description, and impact type
    title_desc = f"{alphabet[plot_index]}) {titles[plot_index]}"
    ax.set_title(title_desc, loc='left', fontsize=12)
    ax.axis('off')

    # Identify the max ADM1_NAME and the top 5 hotspots
    max_adm1 = gdf_merged.loc[gdf_merged[column].idxmax(), 'ADM1_NAME']
    max_adm0 = gdf_merged.loc[gdf_merged[column].idxmax(), 'ISO3']

    max_values.append({
        'ADM1_NAME': max_adm1,
        'ISO3': max_adm0,
    })

    # Extract the top 5 hotspots for the current risk score
    top_5 = gdf_merged.nlargest(5, column)[['ADM1_NAME', 'ISO3', column]]
    top_5_hotspots[description] = top_5

    plot_index += 1

# Adjust the bottom to create space for the colorbar
fig.subplots_adjust(bottom=0.2)

# Add colorbar below the plots
cbar_ax = fig.add_axes([0.2, 0.05, 0.6, 0.03])
cbar = fig.colorbar(plt.cm.ScalarMappable(cmap=cmap, norm=norm), cax=cbar_ax, orientation='horizontal')
cbar.set_label('Risk score', fontsize=18)
cbar.set_ticks([])

# Save the max values
df_max_values = pd.DataFrame(max_values)
df_max_values.to_csv("max_values_table.csv", index=False)

# Save the plot
#plt.savefig(FIGURES / f"hotspot.png", dpi=400, bbox_inches='tight')

# Display the plot
plt.show()

# Print or save the top 5 hotspots table
for desc, top5 in top_5_hotspots.items():
    print(f"Top 5 Hotspots for {desc}:\n", top5.to_string(index=False), "\n")
# Out:
# /var/folders/f5/lms0b90j1kx7kk4v552qkjqw0000gp/T/ipykernel_37405/2727883166.py:17: DtypeWarning: Columns (7,8,9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   agg_regions = pd.read_csv(DATA_DIR / "population/all_worldpop_admin_by_point.csv")
# Top 5 Hotspots for One or more: all (absolute):
#         ADM1_NAME ISO3  Normalized Risk Score
#    Uttar Pradesh  IND               1.000000
# Jiangsu Province  CHN               0.660275
#   Henan Province  CHN               0.557505
#            Bih?r  IND               0.536504
#      West Bengal  IND               0.536064
#
# Top 5 Hotspots for One or more: all (relative):
#             ADM1_NAME ISO3  Normalized Risk Score
#            Flevoland  NLD               1.000000
# Damietta Governorate  EGY               0.991381
#             An Giang  VNM               0.951949
#     Astrakhan Oblast  RUS               0.897084
#        Noord-Holland  NLD               0.860177
#
# Top 5 Hotspots for Three or more: all (absolute):
#          ADM1_NAME ISO3  Normalized Risk Score
#  Jiangsu Province  CHN               1.000000
# Shandong Province  CHN               0.433372
#    Henan Province  CHN               0.420839
#    Anhui Province  CHN               0.362915
#        California  USA               0.355647
#
# Top 5 Hotspots for Three or more: all (relative):
#         ADM1_NAME ISO3  Normalized Risk Score
#   Sakha Republic  RUS               1.000000
#    ALTO PARAGUAY  PRY               0.947188
# Astrakhan Oblast  RUS               0.724518
#          AMAMBAY  PRY               0.689309
#         Taichung  TWN               0.603719
#
# Top 5 Hotspots for Under 5 (relative):
#           ADM1_NAME ISO3  Normalized Risk Score
#      ALTO PARAGUAY  PRY               1.000000
#            AMAMBAY  PRY               0.681500
#             Hà Nam  VNM               0.651283
# Jerusalem District  ISR               0.629390
#     Sakha Republic  RUS               0.628754
#
# Top 5 Hotspots for Over 65 (relative):
#             ADM1_NAME ISO3  Normalized Risk Score
#     Astrakhan Oblast  RUS               1.000000
#  Wakayama Prefecture  JPN               0.797201
#     Kochi Prefecture  JPN               0.749447
# Tokushima Prefecture  JPN               0.739707
#       CASTELO BRANCO  PRT               0.739337

# %%
# we adapt the risks scores to cover different continents/hazards combinations based on areas highlighted on the maps

df_max_values.at[5, 'ADM1_NAME'] = 'Wakayama Prefecture'
df_max_values.at[5, 'ISO3'] = 'JPN'

df_max_values.at[2, 'ADM1_NAME'] = 'California'
df_max_values.at[2, 'ISO3'] = 'USA'

df_max_values.at[1, 'ADM1_NAME'] = 'Kwango'
df_max_values.at[1, 'ISO3'] = 'COD'

# %%
df_max_values
# Out:
#              ADM1_NAME ISO3
# 0        Uttar Pradesh  IND
# 1               Kwango  DRC
# 2     Jiangsu Province  CHN
# 3           California  USA
# 4        ALTO PARAGUAY  PRY
# 5  Wakayama Prefecture  JPN

# %%
import scipy.sparse as sp
import climada.util.coordinates as u_coord
import copy
import datetime
import xarray as xr
import copy
import datetime
import pandas as pd
import numpy as np
pair_tuple_keys = [key for key in imp_combined.keys() if len(key) == 5]
single_tuple_keys = [key for key in imp_combined.keys() if len(key) == 3]

# %%
age = "all" # for the rest of the plots we work with all ages
imp_combined_at_reg = {}
for combi in combinations:
    imp_combined_at_reg[combi]=imp_combined[age][combi].impact_at_reg(agg_regions=agg_regions['numeric'])

for combi in imp_combined_at_reg:
    at_reg = copy.deepcopy(imp_combined_at_reg[combi])
    at_reg['month'] = [datetime.datetime.fromordinal(int(date)).month for date in imp_combined[age][combi].date]
    at_reg['year'] = [datetime.datetime.fromordinal(int(date)).year for date in imp_combined[age][combi].date]

    melted_df1 = at_reg.melt(id_vars=['month', 'year'], var_name='numeric', value_name='impact')
    melted_df1 = melted_df1.merge(agg_regions[["numeric","ADM1_NAME", "ADM1_ID"]].drop_duplicates())

# %%
import matplotlib.pyplot as plt
from cartopy import crs
import geopandas as gpd

rel_country_imp = {}
mean_rel_country_imp = {}

for combi in hazards:

    at_reg = imp_combined[age][combi].impact_at_reg(agg_regions=agg_regions['numeric'])
    
    # Prepare the data for plotting
    at_reg['month'] = [datetime.datetime.fromordinal(int(date)).month for date in imp_combined[age][combi].date]
    at_reg['year'] = [datetime.datetime.fromordinal(int(date)).year for date in imp_combined[age][combi].date]
    
    # Melt and merge data
    at_reg_melted = at_reg.melt(id_vars=['month', 'year'], var_name='numeric', value_name='impact')
    at_reg_melted = at_reg_melted.merge(agg_regions[["ADM1_ID", "ADM1_NAME", "ISO3", "numeric"]].drop_duplicates())
    at_reg_melted = at_reg_melted.merge(adm1_pop_by_year, on=['year', "ADM1_ID", "ADM1_NAME", "ISO3"], how='inner')

    
    at_reg_melted['relative_impact'] = at_reg_melted['impact'] / at_reg_melted['value']

    rel_country_imp[combi] = at_reg_melted

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import numpy as np
from matplotlib.lines import Line2D

# Define colors and transparency for different event types
colors_dict = {
    "FI": "orange", 
    "HW": "red", 
    "DR": "black", 
    "TC": "purple", 
    "RF": "blue", 
    "EP": "lightblue",
}

alpha_dict = {
    "FI": 0.2, 
    "HW": 0.2, 
    "DR": 0.3, 
    "TC": 0.5, 
    "RF": 0.5, 
    "EP": 0.5,
}

# Labels for the legend
legend_labels_median = [
    "Flood Exposure (FI)", 
    "Heatwave Exposure (HW)", 
    "Drought Exposure (DR)", 
    "Tropical Cyclone Exposure (TC)", 
    "Epidemic Exposure (EP)", 
    "Rainfall Exposure (RF)"
]

legend_labels_variability = [
    "FI Variability", 
    "HW Variability", 
    "DR Variability", 
    "TC Variability", 
    "EP Variability", 
    "RF Variability"
]

# Initialize the figure with a larger size
fig = plt.figure(figsize=(24, 38))
gs = gridspec.GridSpec(nrows=12, ncols=2, height_ratios=[1, 0.5] * 6, hspace=0.3, wspace=0.3)

# Loop through each region (ADM1_NAME) to create subplots
for i, adm1_name in enumerate(df_max_values["ADM1_NAME"]):
    # Determine position in the grid
    col = i % 2
    row_main = (i // 2) * 2
    row_rf = row_main + 1

    # Create the main and secondary axes
    ax_main = fig.add_subplot(gs[row_main, col])
    ax_rf = fig.add_subplot(gs[row_rf, col])

    # Initialize variables to track the maximum impact
    max_relative_impact = 0
    max_impact = 0

    # Plot data for all events except "RF"
    for key in colors_dict:
        if key != "RF":
            data = rel_country_imp[key][rel_country_imp[key].ADM1_NAME == adm1_name][["impact", "relative_impact", "month"]]
            if data['impact'].sum() > 100:  # Only plot if total impact is significant
                median_values = data.groupby("month").median()
                lower_bound = data.groupby("month").quantile(0.05)
                upper_bound = data.groupby("month").quantile(0.95)
                
                ax_main.plot(median_values.index, median_values['impact'] / 1000, color=colors_dict[key])
                ax_main.fill_between(median_values.index, lower_bound['impact']/1000, upper_bound['impact']/1000, 
                                     alpha=alpha_dict[key], color=colors_dict[key])

                # Track the maximum values for scaling the axes
                max_relative_impact = max(max_relative_impact, data['relative_impact'].max())
                max_impact = max(max_impact, data['impact'].max()/1000)

    # Plot data for the "RF" event separately
    data_rf = rel_country_imp["RF"][rel_country_imp["RF"].ADM1_NAME == adm1_name][["impact", "relative_impact", "month"]]
    median_values_rf = data_rf.groupby("month").median()
    lower_bound_rf = data_rf.groupby("month").quantile(0.05)
    upper_bound_rf = data_rf.groupby("month").quantile(0.95)
    ax_rf.plot(median_values_rf.index, median_values_rf['impact'] / 1000, color=colors_dict["RF"], label=adm1_name)
    ax_rf.fill_between(median_values_rf.index, lower_bound_rf['impact']/1000, upper_bound_rf['impact']/1000, 
                       alpha=alpha_dict["RF"], color=colors_dict["RF"])

    # Create a secondary y-axis for relative impact
    secax_rf = ax_rf.twinx()
    max_relative_impact_rf = data_rf['relative_impact'].max()
    max_impact_rf = data_rf['impact'].max()/1000
    secax_rf.set_ylim(0, max_relative_impact_rf * 100)
    ax_rf.set_ylim(0, max_impact_rf)

    # Set titles and labels
    country_code = np.array(adm1_pop_by_year['ISO3'][adm1_pop_by_year['ADM1_NAME'] == adm1_name])[0]
    ax_main.set_title(f"{adm1_name}, {country_code}", fontsize=18)
    ax_main.tick_params(axis='both', which='major', labelsize=18)
    ax_main.set_xticklabels([])
    ax_main.set_ylim(0, max_impact)

    # Secondary y-axis for population exposed percentage
    secax = ax_main.twinx()
    secax.set_ylim(0, max_relative_impact * 100)
    if col == 1:
        secax.set_ylabel('Population exposed (%)', fontsize=18, labelpad=20)
    secax.tick_params(axis='both', which='major', labelsize=18)
    secax.set_xticklabels([])

    if col == 0:
        ax_main.set_ylabel('People exposed (thousands)', fontsize=18, labelpad=20)

    ax_rf.tick_params(axis='both', which='major', labelsize=18)
    secax_rf.tick_params(axis='both', which='major', labelsize=18)

    # Only set the xlabel for the last row
    if i // 2 == (len(df_max_values.ADM1_NAME) - 1) // 2:
        ax_rf.set_xlabel('Month', fontsize=18)
    else:
        ax_rf.set_xticklabels([])

# Create custom legend handles for the median and variability
custom_lines_median = [Line2D([0], [0], color=colors_dict[key], lw=2) for key in colors_dict]
custom_lines_variability = [Line2D([0], [0], color=colors_dict[key], lw=4, alpha=0.2) for key in colors_dict]

# Place legends at the top of the figure
leg1 = fig.legend(custom_lines_median, legend_labels_median, loc='upper left', fontsize=18, title='Median', bbox_to_anchor=(0.12, 0.965), title_fontsize=18)
leg2 = fig.legend(custom_lines_variability, legend_labels_variability, loc='upper left', fontsize=18, title='Variability', bbox_to_anchor=(0.35, 0.965), title_fontsize=18)

# Add the legends to the figure
fig.add_artist(leg1)
fig.add_artist(leg2)
plt.tight_layout()

#plt.savefig(FIGURES / "seasonality.pdf", bbox_inches='tight')
plt.show()
# Out:
# /var/folders/f5/lms0b90j1kx7kk4v552qkjqw0000gp/T/ipykernel_37405/910266759.py:134: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
age = 'all'
imp_combined_adm1 = {}
for adm1 in df_max_values["ADM1_NAME"]:
    imp_combined_adm1[adm1] = {}
    for combi in imp_combined[age]:
        adm0 = np.array(df_max_values["ISO3"][df_max_values["ADM1_NAME"]==adm1])[0]

        region_num = agg_regions[agg_regions.ISO3==adm0]["numeric"]
        print(combi)
        imp_combined_adm1[adm1][combi] = impact_select_region(imp_combined[age][combi], agg_regions.numeric, region_num)
        imp_combined_adm1[adm1][combi].unit = "people"
        imp_combined_adm1[adm1][combi].eai_exp = np.array(imp_combined_adm1[adm1][combi].imp_mat.mean(axis=0).flatten())[0]
# Out:
# RF
# EP
# DR
# HW
# FI
# TC
# RF-EP
# RF-DR
# RF-HW
# RF-FI
# RF-TC
# EP-DR
# EP-HW
# EP-FI
# EP-TC
# DR-HW
# DR-FI
# DR-TC
# HW-FI
# HW-TC
# FI-TC
# RF-EP-DR
# RF-EP-HW
# RF-EP-FI
# RF-EP-TC
# RF-DR-HW
# RF-DR-FI
# RF-DR-TC
# RF-HW-FI
# RF-HW-TC
# RF-FI-TC
# EP-DR-HW
# EP-DR-FI
# EP-DR-TC
# EP-HW-FI
# EP-HW-TC
# EP-FI-TC
# DR-HW-FI
# DR-HW-TC
# DR-FI-TC
# HW-FI-TC
# RF-EP-DR-HW
# RF-EP-DR-FI
# RF-EP-DR-TC
# RF-EP-HW-FI
# RF-EP-HW-TC
# RF-EP-FI-TC
# RF-DR-HW-FI
# RF-DR-HW-TC
# RF-DR-FI-TC
# RF-HW-FI-TC
# EP-DR-HW-FI
# EP-DR-HW-TC
# EP-DR-FI-TC
# EP-HW-FI-TC
# DR-HW-FI-TC
# RF-EP-DR-HW-FI
# RF-EP-DR-HW-TC
# RF-EP-DR-FI-TC
# RF-EP-HW-FI-TC
# RF-DR-HW-FI-TC
# EP-DR-HW-FI-TC
# RF-EP-DR-HW-FI-TC
# RF
# EP
# DR
# HW
# FI
# TC
# RF-EP
# RF-DR
# RF-HW
# RF-FI
# RF-TC
# EP-DR
# EP-HW
# EP-FI
# EP-TC
# DR-HW
# DR-FI
# DR-TC
# HW-FI
# HW-TC
# FI-TC
# RF-EP-DR
# RF-EP-HW
# RF-EP-FI
# RF-EP-TC
# RF-DR-HW
# RF-DR-FI
# RF-DR-TC
# RF-HW-FI
# RF-HW-TC
# RF-FI-TC
# EP-DR-HW
# EP-DR-FI
# EP-DR-TC
# EP-HW-FI
# EP-HW-TC
# EP-FI-TC
# DR-HW-FI
# DR-HW-TC
# DR-FI-TC
# HW-FI-TC
# RF-EP-DR-HW
# RF-EP-DR-FI
# RF-EP-DR-TC
# RF-EP-HW-FI
# RF-EP-HW-TC
# RF-EP-FI-TC
# RF-DR-HW-FI
# RF-DR-HW-TC
# RF-DR-FI-TC
# RF-HW-FI-TC
# EP-DR-HW-FI
# EP-DR-HW-TC
# EP-DR-FI-TC
# EP-HW-FI-TC
# DR-HW-FI-TC
# RF-EP-DR-HW-FI
# RF-EP-DR-HW-TC
# RF-EP-DR-FI-TC
# RF-EP-HW-FI-TC
# RF-DR-HW-FI-TC
# EP-DR-HW-FI-TC
# RF-EP-DR-HW-FI-TC
# RF
# EP
# DR
# HW
# FI
# TC
# RF-EP
# RF-DR
# RF-HW
# RF-FI
# RF-TC
# EP-DR
# EP-HW
# EP-FI
# EP-TC
# DR-HW
# DR-FI
# DR-TC
# HW-FI
# HW-TC
# FI-TC
# RF-EP-DR
# RF-EP-HW
# RF-EP-FI
# RF-EP-TC
# RF-DR-HW
# RF-DR-FI
# RF-DR-TC
# RF-HW-FI
# RF-HW-TC
# RF-FI-TC
# EP-DR-HW
# EP-DR-FI
# EP-DR-TC
# EP-HW-FI
# EP-HW-TC
# EP-FI-TC
# DR-HW-FI
# DR-HW-TC
# DR-FI-TC
# HW-FI-TC
# RF-EP-DR-HW
# RF-EP-DR-FI
# RF-EP-DR-TC
# RF-EP-HW-FI
# RF-EP-HW-TC
# RF-EP-FI-TC
# RF-DR-HW-FI
# RF-DR-HW-TC
# RF-DR-FI-TC
# RF-HW-FI-TC
# EP-DR-HW-FI
# EP-DR-HW-TC
# EP-DR-FI-TC
# EP-HW-FI-TC
# DR-HW-FI-TC
# RF-EP-DR-HW-FI
# RF-EP-DR-HW-TC
# RF-EP-DR-FI-TC
# RF-EP-HW-FI-TC
# RF-DR-HW-FI-TC
# EP-DR-HW-FI-TC
# RF-EP-DR-HW-FI-TC
# RF
# EP
# DR
# HW
# FI
# TC
# RF-EP
# RF-DR
# RF-HW
# RF-FI
# RF-TC
# EP-DR
# EP-HW
# EP-FI
# EP-TC
# DR-HW
# DR-FI
# DR-TC
# HW-FI
# HW-TC
# FI-TC
# RF-EP-DR
# RF-EP-HW
# RF-EP-FI
# RF-EP-TC
# RF-DR-HW
# RF-DR-FI
# RF-DR-TC
# RF-HW-FI
# RF-HW-TC
# RF-FI-TC
# EP-DR-HW
# EP-DR-FI
# EP-DR-TC
# EP-HW-FI
# EP-HW-TC
# EP-FI-TC
# DR-HW-FI
# DR-HW-TC
# DR-FI-TC
# HW-FI-TC
# RF-EP-DR-HW
# RF-EP-DR-FI
# RF-EP-DR-TC
# RF-EP-HW-FI
# RF-EP-HW-TC
# RF-EP-FI-TC
# RF-DR-HW-FI
# RF-DR-HW-TC
# RF-DR-FI-TC
# RF-HW-FI-TC
# EP-DR-HW-FI
# EP-DR-HW-TC
# EP-DR-FI-TC
# EP-HW-FI-TC
# DR-HW-FI-TC
# RF-EP-DR-HW-FI
# RF-EP-DR-HW-TC
# RF-EP-DR-FI-TC
# RF-EP-HW-FI-TC
# RF-DR-HW-FI-TC
# EP-DR-HW-FI-TC
# RF-EP-DR-HW-FI-TC
# RF
# EP
# DR
# HW
# FI
# TC
# RF-EP
# RF-DR
# RF-HW
# RF-FI
# RF-TC
# EP-DR
# EP-HW
# EP-FI
# EP-TC
# DR-HW
# DR-FI
# DR-TC
# HW-FI
# HW-TC
# FI-TC
# RF-EP-DR
# RF-EP-HW
# RF-EP-FI
# RF-EP-TC
# RF-DR-HW
# RF-DR-FI
# RF-DR-TC
# RF-HW-FI
# RF-HW-TC
# RF-FI-TC
# EP-DR-HW
# EP-DR-FI
# EP-DR-TC
# EP-HW-FI
# EP-HW-TC
# EP-FI-TC
# DR-HW-FI
# DR-HW-TC
# DR-FI-TC
# HW-FI-TC
# RF-EP-DR-HW
# RF-EP-DR-FI
# RF-EP-DR-TC
# RF-EP-HW-FI
# RF-EP-HW-TC
# RF-EP-FI-TC
# RF-DR-HW-FI
# RF-DR-HW-TC
# RF-DR-FI-TC
# RF-HW-FI-TC
# EP-DR-HW-FI
# EP-DR-HW-TC
# EP-DR-FI-TC
# EP-HW-FI-TC
# DR-HW-FI-TC
# RF-EP-DR-HW-FI
# RF-EP-DR-HW-TC
# RF-EP-DR-FI-TC
# RF-EP-HW-FI-TC
# RF-DR-HW-FI-TC
# EP-DR-HW-FI-TC
# RF-EP-DR-HW-FI-TC
# RF
# EP
# DR
# HW
# FI
# TC
# RF-EP
# RF-DR
# RF-HW
# RF-FI
# RF-TC
# EP-DR
# EP-HW
# EP-FI
# EP-TC
# DR-HW
# DR-FI
# DR-TC
# HW-FI
# HW-TC
# FI-TC
# RF-EP-DR
# RF-EP-HW
# RF-EP-FI
# RF-EP-TC
# RF-DR-HW
# RF-DR-FI
# RF-DR-TC
# RF-HW-FI
# RF-HW-TC
# RF-FI-TC
# EP-DR-HW
# EP-DR-FI
# EP-DR-TC
# EP-HW-FI
# EP-HW-TC
# EP-FI-TC
# DR-HW-FI
# DR-HW-TC
# DR-FI-TC
# HW-FI-TC
# RF-EP-DR-HW
# RF-EP-DR-FI
# RF-EP-DR-TC
# RF-EP-HW-FI
# RF-EP-HW-TC
# RF-EP-FI-TC
# RF-DR-HW-FI
# RF-DR-HW-TC
# RF-DR-FI-TC
# RF-HW-FI-TC
# EP-DR-HW-FI
# EP-DR-HW-TC
# EP-DR-FI-TC
# EP-HW-FI-TC
# DR-HW-FI-TC
# RF-EP-DR-HW-FI
# RF-EP-DR-HW-TC
# RF-EP-DR-FI-TC
# RF-EP-HW-FI-TC
# RF-DR-HW-FI-TC
# EP-DR-HW-FI-TC
# RF-EP-DR-HW-FI-TC

# %%
agg_regions.ISO3.unique()
# Out:
# array([nan, 'CHL', 'ARG', 'NZL', 'AUS', 'ZAF', 'URY', 'BRA', 'LSO', 'NAM',
#        'PRY', 'SWZ', 'BWA', 'MOZ', 'MDG', 'BOL', 'ZWE', 'MUS', 'VUT',
#        'FJI', 'PER', 'AGO', 'ZMB', 'MWI', 'USA', 'WSM', 'COD', 'COM',
#        'SLB', 'TZA', 'PNG', 'IDN', 'SYC', 'TLS', 'COG', 'ECU', 'KEN',
#        'BDI', 'COL', 'GAB', 'RWA', 'SOM', 'UGA', 'STP', 'VEN', 'MYS',
#        'GNQ', 'GUY', 'KIR', 'CMR', 'SUR', 'CAF', 'ETH', 'SSD', 'BRN',
#        'NGA', 'LBR', 'CIV', 'PHL', 'GHA', 'THA', 'LKA', 'TGO', 'BEN',
#        'IND', 'PLW', 'FSM', 'SLE', 'PAN', 'GIN', 'TCD', 'CRI', 'SDN',
#        'VNM', 'BFA', 'MMR', 'TTO', 'MLI', 'KHM', 'DJI', 'NIC', 'GNB',
#        'NER', 'ERI', 'YEM', 'SEN', 'HND', 'SLV', 'VCT', 'GMB', 'LAO',
#        'GTM', 'LCA', 'MEX', 'CPV', 'MRT', 'BLZ', 'SAU', 'OMN', 'ATG',
#        'JAM', 'DOM', 'HTI', 'CHN', 'DZA', 'LBY', 'CUB', 'BHS', 'BGD',
#        'EGY', 'TWN', 'ARE', 'PAK', 'JPN', 'QAT', 'IRN', 'BHR', 'NPL',
#        'BTN', 'ESP', 'MAR', 'KWT', 'JOR', 'IRQ', 'AFG', 'ISR', 'TUN',
#        'SYR', 'PRT', 'LBN', 'KOR', 'CYP', 'GRC', 'TKM', 'TUR', 'ITA',
#        'TJK', 'UZB', 'PRK', 'AZE', 'ARM', 'KGZ', 'ALB', 'KAZ', 'MKD',
#        'BGR', 'GEO', 'RUS', 'FRA', 'MNG', 'MNE', 'XKX', 'CAN', 'AND',
#        'SRB', 'HRV', 'BIH', 'ROU', 'UKR', 'SVN', 'MDA', 'CHE', 'HUN',
#        'AUT', 'DEU', 'SVK', 'CZE', 'POL', 'LUX', 'BEL', 'GBR', 'NLD',
#        'BLR', 'IRL', 'LTU', 'DNK', 'SWE', 'LVA', 'EST', 'NOR', 'FIN',
#        'GRL', 'ISL'], dtype=object)

# %%
import matplotlib.pyplot as plt
import geopandas as gpd
import pandas as pd
import numpy as np
from matplotlib.lines import Line2D

# Assuming 'imp_combined_countries', 'risk_score_data', 'colors', 'imp_combined', 'countries', 'FIGURES' are defined elsewhere in your code

plt.rcParams.update({'font.size': 10})  # General font size


# Load the world map
world = gpd.read_file(DATA_DIR / "population/ne_10m_admin_0_countries/ne_10m_admin_0_countries.shp")

# Calculate the number of plots needed
num_plots = 6
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(22, 18))

# Flatten axes for easy iteration
axes = axes.flatten()

plot_index = 0
three_or_more_events = risk_score_data['Three or more: all (relative)']
one_or_more_events = risk_score_data['One or more: all (relative)']
labels = ['a', 'b', 'c', 'd', 'e', 'f']

for i, country in enumerate(df_max_values.ADM1_NAME):
    if plot_index >= num_plots:
        break
    print(country)
    if i == 0 or i == 1:
        one_or_more_events_sel = one_or_more_events[one_or_more_events.ADM1_NAME == country]
        if len(one_or_more_events_sel) > 240:
            continue
    
        one_or_more_events_sel['event_id'] = np.arange(1, len(one_or_more_events_sel) + 1)
        one_or_more_events_max = one_or_more_events_sel.loc[one_or_more_events_sel['relative_impact'].idxmax()]
        event_id = one_or_more_events_max.event_id
        date = f"{one_or_more_events_max.month}/{one_or_more_events_max.year}"
    else:
        three_or_more_events_sel = three_or_more_events[three_or_more_events.ADM1_NAME == country]
        if len(three_or_more_events_sel) > 240:
            continue
    
        three_or_more_events_sel['event_id'] = np.arange(1, len(three_or_more_events_sel) + 1)
        three_or_more_events_max = three_or_more_events_sel.loc[three_or_more_events_sel['relative_impact'].idxmax()]
        event_id = three_or_more_events_max.event_id
        date = f"{three_or_more_events_max.month}/{three_or_more_events_max.year}"
    
    ax = axes[plot_index]
    plot_index += 1

    adm1 = gdf_adm1[gdf_adm1.ADM1_NAME == country]
    cnt = gdf_adm1[gdf_adm1.ADM1_NAME == country].ISO3.iloc[0]

    world.plot(color='whitesmoke', ax=ax, edgecolor='darkgrey')
    adm1.boundary.plot(color='black', ax=ax, linewidth=1)

    plotted_points = set()
    visible_combinations = set()

    # Sort combinations by the number of elements (less complex first)
    sorted_combinations = sorted(imp_combined_adm1[country], key=lambda x: len(x.split('-')))
    sorted_combinations_descending = sorted(imp_combined_adm1[country], key=lambda x: len(x.split('-')), reverse=True)

    # Plot the combinations
    for combi in sorted_combinations:
        gdf = imp_combined[age][combi]._build_exp_event(event_id).gdf  # Adjusted for your data structure

        gdf = gpd.GeoDataFrame(gdf, geometry=gpd.points_from_xy(gdf.longitude, gdf.latitude))
        total_bounds = gdf_adm1[gdf_adm1.ADM1_NAME == country].total_bounds

        minx, miny, maxx, maxy = total_bounds
        filtered_gdf = gdf[
            (gdf.latitude >= miny - 3) & 
            (gdf.latitude <= maxy + 3) & 
            (gdf.longitude >= minx - 4) & 
            (gdf.longitude <= maxx + 4)
        ]

        filtered_gdf = filtered_gdf[filtered_gdf.value > 10]  # Example filter, adjust as necessary
        if len(filtered_gdf) < 10:
            continue

        # Plot the points
        filtered_gdf.plot(marker='o', ax=ax, markersize=70, alpha=0.8, color=colors_dict_combi[combi])
    for combi in sorted_combinations_descending:
        gdf = imp_combined[age][combi]._build_exp_event(event_id).gdf  # Adjusted for your data structure

        gdf = gpd.GeoDataFrame(gdf, geometry=gpd.points_from_xy(gdf.longitude, gdf.latitude))
        total_bounds = gdf_adm1[gdf_adm1.ADM1_NAME == country].total_bounds

        minx, miny, maxx, maxy = total_bounds
        filtered_gdf = gdf[
            (gdf.latitude >= miny - 3) & 
            (gdf.latitude <= maxy + 3) & 
            (gdf.longitude >= minx - 4) & 
            (gdf.longitude <= maxx + 4)
        ]

        filtered_gdf = filtered_gdf[filtered_gdf.value > 10]  # Example filter, adjust as necessary
        if len(filtered_gdf) < 10:
            continue
    
        # Track the points for this combination
        new_points = set(filtered_gdf.geometry.apply(lambda geom: (geom.x, geom.y)))
    
        # Add new points to plotted points
        new_visible_points = new_points - plotted_points
        plotted_points.update(new_points)
    
        # Check if there are new visible points
        if new_visible_points:
            visible_combinations.add(combi)
    
        ax.set_xlim([minx - 4, maxx + 4])
        ax.set_ylim([miny - 3, maxy + 3])
        ax.text(0.05, 0.95, f'({labels[i]})', transform=ax.transAxes, fontsize=14, verticalalignment='top', fontweight='bold', color='black')

        ax.set_title(f'{country}, {cnt} {date}', fontsize=16)  # Smaller title font size

    # Create custom legend handles and labels for the visible combinations
    custom_lines = [Line2D([0], [0], marker='o', color='w', markerfacecolor=colors_dict_combi[combi], markersize=10) for combi in visible_combinations]
    legend_labels = list(visible_combinations)
    
    ax.legend(custom_lines, legend_labels, loc='upper left', fontsize=14, title='Hazard Combinations', title_fontsize=16, bbox_to_anchor=(1, 1))

# Adjust layout with less space between left and right
fig.subplots_adjust(left=0.05, right=0.95, top=0.95, bottom=0.05, hspace=0.2, wspace=0.1)
plt.tight_layout()
# Save the figure
#plt.savefig(FIGURES / f"event_combined.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Uttar Pradesh
# Kwango
