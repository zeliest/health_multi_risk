# %%
import xarray as xr
file = "/Users/szelie/Library/CloudStorage/OneDrive-ETHZurich/data/health_multi_risk_data/PMfire_glob_2003to2021.nc4"
fire = xr.open_dataset(file)

# %% [markdown]
# ### fire

# %%
fire = fire.rename({'lat':'latitude', 'lon':'longitude'})

# %%
fire_monthly = fire.resample(time='M').max()

# %%
import pandas as pd
import numpy as np
from climada.hazard import Hazard
# Rename columns

# Extract years from the `time` dimension
years = pd.to_datetime(fire['time'].values).year
unique_years = np.unique(years)

# Initialize an empty list to store the hazards
yearly_hazards = {}

# Loop over each unique year
for year in unique_years:
    # Extract data for that year
    mask = (pd.to_datetime(fire_monthly['time'].values).year == year)
    yearly_fire_data = fire_monthly.isel(time=mask)

    # Convert it into a hazard
    yearly_hazard = Hazard.from_xarray_raster(yearly_fire_data, hazard_type='pm25', intensity_unit='kg/m3', intensity='cnc_PM_FRP_m_17')
    yearly_hazard.intensity.data[yearly_hazard.intensity.data<1e-9] = 0
    yearly_hazard.intensity.eliminate_zeros()
    # Append the hazard to the list
    yearly_hazards[year] = yearly_hazard

## Store the hazards in the hazards dictionary
#hazards['pm25_fire'] = Hazard.concat(yearly_hazards)

# %%
from pathlib import Path
from climada.entity import Exposures
import numpy as np
exposures_dict = {}
path_exposures = Path("/Users/szelie/OneDrive - ETH Zurich/data/health_multi_risk_data/exposures")


for age in ['0_1']:#,'65_70_75_80','all']:
    exposures_dict[age] = {}
    for year in np.arange(2003, 2023):
        year = str(year)
        exposures_dict[age][year] = Exposures.from_hdf5(path_exposures / f"{age}_era5_025_compatible_{year}.hdf5")
        exposures_dict[age][year].gdf["impf_pm25"] = 1 
        exposures_dict[age][year].gdf['longitude'] = exposures_dict[age][year].gdf['longitude'].apply(lambda x: x - 360 if x > 180 else x)
        exposures_dict[age][year].gdf['value'][exposures_dict[age][year].gdf['value']<0] = 0

# %%
exposures_dict['65_70_75_80']['2000'].gdf
# Out:
#          latitude  longitude  age_band_lower_bound  value  impf_pm25
# 0           -90.0       0.00                    65    0.0          1
# 1           -90.0       0.25                    65    0.0          1
# 2           -90.0       0.50                    65    0.0          1
# 3           -90.0       0.75                    65    0.0          1
# 4           -90.0       1.00                    65    0.0          1
# ...           ...        ...                   ...    ...        ...
# 1038235      90.0      -1.25                    65    0.0          1
# 1038236      90.0      -1.00                    65    0.0          1
# 1038237      90.0      -0.75                    65    0.0          1
# 1038238      90.0      -0.50                    65    0.0          1
# 1038239      90.0      -0.25                    65    0.0          1
#
# [1038240 rows x 5 columns]

# %%
from climada.entity.impact_funcs import ImpactFunc, ImpactFuncSet

impf_set = ImpactFuncSet()

impf25 = ImpactFunc()
impf25.id = 1
impf25.haz_type = 'pm25'
impf25.name = 'Step function pm2.5'
impf25.intensity_unit = ''
impf25.intensity = np.array([0, 1.4e-8, 1.5e-8, 1])
impf25.mdd = np.array([0, 0, 1, 1])
impf25.paa = np.ones(impf25.intensity.shape)
impf25.check()
impf_set.append(impf25)

# %%
yearly_hazards[year].intensity
# Out:
# 5.022101e-06

# %%
from climada.engine import Impact, ImpactCalc

impact_dict = {age: {year:ImpactCalc(exposures_dict[age][str(year)], impf_set, yearly_hazards[year]).impact(save_mat=True) for year in yearly_hazards} for age in exposures_dict}


impact_dict_no_change_vuln_pop = {age: {year:ImpactCalc(exposures_dict[age]['2003'], impf_set, yearly_hazards[year]).impact(save_mat=True) for year in yearly_hazards} for age in exposures_dict}

for age in impact_dict:
    for year in impact_dict[age]:
        impact_dict[age][year].tot_value=0
        impact_dict_no_change_vuln_pop[age][year].tot_value=0
# Out:
# 2024-04-13 14:10:04,282 - climada.util.coordinates - WARNING - Distance to closest centroid is greater than 100km for 5760 coordinates.
# 2024-04-13 14:10:04,368 - climada.util.coordinates - WARNING - Distance to closest centroid is greater than 100km for 36 coordinates.
# 2024-04-13 14:10:06,052 - climada.util.coordinates - WARNING - Distance to closest centroid is greater than 100km for 5760 coordinates.
# 2024-04-13 14:10:06,174 - climada.util.coordinates - WARNING - Distance to closest centroid is greater than 100km for 36 coordinates.
# 2024-04-13 14:10:07,751 - climada.util.coordinates - WARNING - Distance to closest centroid is greater than 100km for 5760 coordinates.
# 2024-04-13 14:10:07,833 - climada.util.coordinates - WARNING - Distance to closest centroid is greater than 100km for 36 coordinates.
# 2024-04-13 14:10:09,368 - climada.util.coordinates - WARNING - Distance to closest centroid is greater than 100km for 5760 coordinates.
# ...

# %%
impact_concat = {}
impact_concat_no_change_vuln_pop = {}
for age in impact_dict:
    impact_concat[age] = Impact.concat(list(impact_dict[age].values()),reset_event_ids=True)
    impact_concat_no_change_vuln_pop[age] = Impact.concat(list(impact_dict_no_change_vuln_pop[age].values()),reset_event_ids=True)
# Out:
# 2024-04-13 14:11:05,026 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# 2024-04-13 14:11:05,027 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# 2024-04-13 14:11:05,028 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# 2024-04-13 14:11:05,028 - climada.engine.impact - WARNING - The Impact.tot_value attribute is deprecated.Use Exposures.affected_total_value to calculate the affected total exposure value based on a specific hazard intensity threshold
# ...

# %%
impact_concat['0'].at_event
# Out:
# array([ 2830383.85139181,  1844182.08582533,  4566224.16456645,
#         3906012.36981603,  7496810.44989114,  7599346.97983512,
#         7388659.33085357,  8447462.30661593,  4614887.64869715,
#         3853987.78498203,  1697707.95597602,  2433430.25600957,
#         1636000.44952416,  6279375.60124198,  5607853.56647225,
#         1538755.14726539,  2678206.06014212,  7671325.47513654,
#         7398762.62048377,  5374305.01916071,  4439402.61363725,
#         5243836.89611236,  1047130.6575408 ,  2458864.74414857,
#         6791671.80385919,  2133859.31533206,  3772048.53901759,
#         3909066.76292689,  2125820.53732454,  8587429.55822636,
#         8525102.08378975, 10167718.48899456,  4717292.93765182,
#         4118255.12373039,  2776650.13134554,  2122010.13465443,
#         1996277.00081507,   818402.91751663,  3760898.17034752,
#         3315038.88543678,  2047364.71491162,  4821137.6429201 ,
#         7813954.00885673, 10395371.24410072,  6590216.70398444,
# ...

# %%
import matplotlib.pyplot as plt
from datetime import datetime
date = [datetime.fromordinal(date) for date in impact_concat[age].date]

# Sample data for demonstration
# (Replace with your actual data)
# date = ...
# impact_concat = ...
# impact_concat_no_change_vuln_pop = ...

fig, ax = plt.subplots(figsize=(14,6))
ax.scatter(date, impact_concat[age].at_event, alpha=0.8, label="changes in climatee& population")
ax.scatter(date, impact_concat_no_change_vuln_pop[age].at_event, alpha=0.8, label="changes in climate")

# Identify the indices of the top 8 maximum values for impact_concat
sorted_indices = impact_concat[age].at_event.argsort()
top_8_indices = sorted_indices[-8:]  # indices of the top 8 maximum values

# Annotate the top 8 maximum values for impact_concat
for idx in top_8_indices:
    ax.annotate(date[idx], (date[idx], impact_concat[age].at_event[idx]), fontsize=9, ha='right')

ax.set_title("Change in vulnerable population exposed (only climate)")
ax.legend()
plt.show()

# %%
from shapely.geometry import Point

gdf_data = impact_concat['all']._build_exp_event(impact_concat['all'].event_id[np.argmax(impact_concat['all'].at_event)]).gdf
geometry = [Point(xy) for xy in zip(gdf_data.longitude, gdf_data.latitude)]
gdf_data = gpd.GeoDataFrame(gdf_data, geometry=geometry)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 3
#       1 from shapely.geometry import Point
# ----> 3 gdf_data = impact_concat['all']._build_exp_event(impact_concat['all'].event_id[np.argmax(impact_concat['all'].at_event)]).gdf
#       4 geometry = [Point(xy) for xy in zip(gdf_data.longitude, gdf_data.latitude)]
#       5 gdf_data = gpd.GeoDataFrame(gdf_data, geometry=geometry)
#
# KeyError: 'all'

# %%
for age in impact_dict:
    impact_concat[age].write_csv(f"/Users/szelie/Library/CloudStorage/OneDrive-ETHZurich/data/health_multi_risk_data/impacts/fi_{age}_2000_2021.csv")
    impact_concat[age].write_sparse_csr(f"/Users/szelie/Library/CloudStorage/OneDrive-ETHZurich/data/health_multi_risk_data/impacts/fi_{age}_2000_2021.npz")

# %%
impact_dict.keys()
# Out:
# dict_keys(['0', '65_70_75_80', 'all'])

# %%
from cartopy import crs
import cartopy.feature as cfeature
from geopandas import GeoDataFrame
from shapely.geometry import Point
import matplotlib.pyplot as plt
import geopandas as gpd

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(1, 1, 1, projection=crs.PlateCarree())
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS)
gdf_data[gdf_data.value > 0].plot(column="value", vmax=10000, s=1, ax=ax, legend=True)
# Out:
# <GeoAxes: >

# %%
impact_concat
# Out:
# {'0': <climada.engine.impact.Impact at 0x197f257d0>,
#  '65_70_75_80': <climada.engine.impact.Impact at 0x1981ad390>,
#  'all': <climada.engine.impact.Impact at 0x1984f9910>}

# %%
from shapely.geometry import Point

gdf_data = impact_concat['all']._build_exp().gdf
geometry = [Point(xy) for xy in zip(gdf_data.longitude, gdf_data.latitude)]
gdf_data = gpd.GeoDataFrame(gdf_data, geometry=geometry)
gdf_data["value"] = gdf_data["value"]/19

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(1, 1, 1, projection=crs.PlateCarree())
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS)
gdf_data[gdf_data.value > 0].plot(column="value", vmax=10000, s=1, ax=ax, legend=True)
# Out:
# <GeoAxes: >
